# %%
# %matplotlib widget

import inspect
import re
def debugPrint(x):
    frame = inspect.currentframe().f_back
    s = inspect.getframeinfo(frame).code_context[0]
    r = re.search(r"\((.*)\)", s).group(1)
    print("{} [{}] = {}".format(r,type(x).__name__, x))


import h5py
import os
import numpy as np
from tqdm.autonotebook import tqdm
import os
# Out:
# /tmp/ipykernel_33065/2862113688.py:15: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# directory = '../diffSPH/generative/TGV/export'
# files = os.listdir(directory)
# print(files)

# for file in tqdm(files):
# inFile = h5py.File(f'../diffSPH/generative/TGV/export/{files[0]}', 'r')

# %%
from BasisConvolution.util.hyperparameters import defaultHyperParameters
# Out:
# diffSPH not available, will use sphMath for config parsing

# %%
#  args = parser.parse_args(args) if args is not None else parser.parse_args()
# # args.verbose = True

# hyperParameterDict = parseHyperParameters(args, trainingFiles, config = config if config is not None else (args.cfg if args.cfg != "" else None))
hyperParameterDict = defaultHyperParameters()

# %%
# basePath = '~/dev/diffSPH/generative/dataset_dfsph/export'
# basePath = os.path.expanduser(basePath)
# simulationFiles = sorted([basePath + '/' + f for f in os.listdir(basePath) if f.endswith('.hdf5')])
# inFile_dfsph = h5py.File(simulationFiles[0], 'r')

basePath = '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_II/dataset/train'
basePath = os.path.expanduser(basePath)
simulationFiles = sorted([basePath + '/' + f for f in os.listdir(basePath) if f.endswith('.hdf5')])
inFile_II = h5py.File(simulationFiles[0], 'r')

basePath = '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_III/dataset/train'
basePath = os.path.expanduser(basePath)
simulationFiles = sorted([basePath + '/' + f for f in os.listdir(basePath) if f.endswith('.hdf5')])
inFile_III = h5py.File(simulationFiles[0], 'r')

basePath = '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_IV/dataset'
basePath = os.path.expanduser(basePath)
simulationFiles = sorted([basePath + '/' + f for f in os.listdir(basePath) if f.endswith('.hdf5')])
inFile_IV = h5py.File(simulationFiles[1], 'r')

basePath = '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_I/dataset'
basePath = os.path.expanduser(basePath)
simulationFiles = sorted([basePath + '/' + f for f in os.listdir(basePath) if f.endswith('.hdf5')])
inFile_I = h5py.File(simulationFiles[0], 'r')

# %%
inFiles = [inFile_I, inFile_II, inFile_III, inFile_IV]

for inFile in inFiles:
    print(inFile.filename)
    print(getFrameCount(inFile))
    print(getFrames(inFile))
    print(isTemporalData(inFile))
    print('')
# Out:
# /home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_I/dataset/out_perlin_09771992_2023-10-17_13-48-18.hdf5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 for inFile in inFiles:
#       4     print(inFile.filename)
# ----> 5     print(getFrameCount(inFile))
#       6     print(getFrames(inFile))
#       7     print(isTemporalData(inFile))
#
# NameError: name 'getFrameCount' is not defined

# %%
from BasisConvolution.util.datautils import getSamples, parseFile

hyperParameterDict['maxRollOut'] = 0

print(hyperParameterDict['adjustForFrameDistance'])
print(hyperParameterDict['frameDistance'])
print(hyperParameterDict['dataDistance'])
print(hyperParameterDict['zeroOffset'])
print(hyperParameterDict['maxRollOut'])
print(hyperParameterDict['dataLimit'])


for inFile in inFiles:
    print(inFile.filename)
    # if not isTemporalData(inFile):
        # continue
    parsed = parseFile(inFile, hyperParameterDict)
    # display(parsed)
    print(parsed['style'])
    print(inFile.keys())

    rollout = 8
    frameSpacing = 4
    frameDistance = 8

    # print(isTemporalData(inFile))
    # frames, samples = getSamples(inFile, frameSpacing = frameSpacing, maxRollout = rollout, frameDistance = frameDistance, skip = 4, limit = 1600)
    # print(frames)

    # print(frames[-1], '->', frames[-1] + rollout * frameDistance)
    # # print(getFrames(inFile))
    # # print(isTemporalData(inFile))
    # print('')
# Out:
# True
# 4
# 1
# True
# -1
# /home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_I/dataset/out_perlin_09771992_2023-10-17_13-48-18.hdf5
# testcase_I
# <KeysViewHDF5 ['generatorSettings', 'simulationData']>
# /home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_II/dataset/train/generative - 2023-03-22_14-22-55.hdf5
# testcase_II
# <KeysViewHDF5 ['boundaryInformation', 'simulationExport']>
# /home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_III/dataset/train/collision - 2023-07-31_19-44-26.hdf5
# testcase_II
# <KeysViewHDF5 ['boundaryInformation', 'simulationExport']>
# /home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_IV/dataset/lowJitter.hdf5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 14
#      11 print(inFile.filename)
#      12 # if not isTemporalData(inFile):
#      13     # continue
# ---> 14 parsed = parseFile(inFile, hyperParameterDict)
#      15 # display(parsed)
#      16 print(parsed['style'])
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/datautils.py:318, in parseFile(inFile, hyperParameterDict)
#     314 skip *= frameDistance
#     315 limit = hyperParameterDict['dataLimit'] if 'dataLimit' in hyperParameterDict else 0
# --> 318 frames, samples = getSamples(inFile, frameSpacing = frameSpacing, frameDistance = frameDistance, maxRollout = maxRollout, skip = skip, limit = limit)
#     320 data= {'fileName': inFile.filename, 'frames': frames, 'samples': samples, 'frameDistance': frameDistance, 'frameSpacing': frameSpacing, 'maxRollout': maxRollout, 'skip': skip, 'limit': limit, 'isTemporalData': temporalData, 'style': getStyle(inFile)}
#     321 # print(data)
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/datautils.py:257, in getSamples(inFile, frameSpacing, frameDistance, maxRollout, skip, limit)
#     254 frames, samples = getFrames(inFile)
#     256 if maxRollout > 0 and not temporalData:
# --> 257     raise ValueError('Max rollout only supported for temporal data')
#     258 if frameCount < maxRollout:
#     259     raise ValueError('Max rollout larger than frame count')
#
# ValueError: Max rollout only supported for temporal data

# %%
from BasisConvolution.util.dataloader import datasetLoader, processFolder#, DataLoader
from torch.utils.data import DataLoader

# %%
# basePaths  = [
#     # '~/dev/diffSPH/generative/dataset_dfsph/export',
#     '~/dev/SFBC/datasets/test_case_II/train',
#     '~/dev/SFBC/datasets/test_case_III/train',
#     '~/dev/SFBC/datasets/test_case_IV',
#     '~/dev/SFBC/datasets/test_case_I',
# ]

# loaders = []

# for basePath in basePaths:

#     loader = datasetLoader(processFolder(hyperParameterDict, basePath))
#     loaders.append(loader)
#     print(basePath, len(loader))

# %%
hyperParameterDict['batch_size'] = 16

# %%
train_ds = datasetLoader(processFolder(hyperParameterDict, '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_I/dataset'))
train_ds = datasetLoader(processFolder(hyperParameterDict, '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_II/dataset/train'))
train_ds = datasetLoader(processFolder(hyperParameterDict, '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_III/dataset/train'))
train_ds = datasetLoader(processFolder(hyperParameterDict, '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_IV/dataset'))
# train_ds = datasetLoader(processFolder(hyperParameterDict, '~/dev/datasets/generative/dataset_dfsph/export'))

train_dataloader = DataLoader(train_ds, shuffle=True, batch_size = hyperParameterDict['batch_size']).batch_sampler
train_iter = iter(train_dataloader)

batch = next(train_iter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       2 train_ds = datasetLoader(processFolder(hyperParameterDict, '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_II/dataset/train'))
#       3 train_ds = datasetLoader(processFolder(hyperParameterDict, '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_III/dataset/train'))
# ----> 4 train_ds = datasetLoader(processFolder(hyperParameterDict, '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_IV/dataset'))
#       5 # train_ds = datasetLoader(processFolder(hyperParameterDict, '~/dev/datasets/generative/dataset_dfsph/export'))
#       7 train_dataloader = DataLoader(train_ds, shuffle=True, batch_size = hyperParameterDict['batch_size']).batch_sampler
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/dataloader.py:50, in processFolder(hyperParameterDict, folder)
#      48 for s in simulationFiles:
#      49     inFile = h5py.File(s, 'r')
# ---> 50     data.append(parseFile(inFile, hyperParameterDict))
#      51     inFile.close()
#      52 return data
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/datautils.py:318, in parseFile(inFile, hyperParameterDict)
#     314 skip *= frameDistance
#     315 limit = hyperParameterDict['dataLimit'] if 'dataLimit' in hyperParameterDict else 0
# --> 318 frames, samples = getSamples(inFile, frameSpacing = frameSpacing, frameDistance = frameDistance, maxRollout = maxRollout, skip = skip, limit = limit)
#     320 data= {'fileName': inFile.filename, 'frames': frames, 'samples': samples, 'frameDistance': frameDistance, 'frameSpacing': frameSpacing, 'maxRollout': maxRollout, 'skip': skip, 'limit': limit, 'isTemporalData': temporalData, 'style': getStyle(inFile)}
#     321 # print(data)
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/datautils.py:257, in getSamples(inFile, frameSpacing, frameDistance, maxRollout, skip, limit)
#     254 frames, samples = getFrames(inFile)
#     256 if maxRollout > 0 and not temporalData:
# --> 257     raise ValueError('Max rollout only supported for temporal data')
#     258 if frameCount < maxRollout:
#     259     raise ValueError('Max rollout larger than frame count')
#
# ValueError: Max rollout only supported for temporal data

# %%
from BasisConvolution.util.testcases import loadFrame
from BasisConvolution.util.augment import augmentStates
from BasisConvolution.util.radius import searchNeighbors
from BasisConvolution.util.augment import loadAugmentedFrame
from BasisConvolution.util.radius import countUnique
import torch
from BasisConvolution.util.features import getFeatures

import matplotlib.pyplot as plt
import copy
from BasisConvolution.util.augment import augmentState
from BasisConvolution.util.plotting import prepVisualizationState, visualizeParticleQuantity

from BasisConvolution.sph.sphOps import sphOperationStates

# %%
from BasisConvolution.util.dataPlotting import getFileCount, getPreparePlotFunction, getUpdatePlotFunction
import matplotlib.pyplot as plt
import ipywidgets as widgets

# datasetPath = 'datasets/SFBC_dataset_I/dataset'
# datasetPath = 'datasets/SFBC_dataset_II/dataset/train'
# datasetPath = 'datasets/SFBC_dataset_III/dataset/train'
datasetPath = '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_IV/dataset'

train_ds = datasetLoader(processFolder(hyperParameterDict, datasetPath))

plotState = getPreparePlotFunction(train_ds.fileFormat)(train_ds, hyperParameterDict)
updateFn = getUpdatePlotFunction(train_ds.fileFormat)

dropdown = widgets.Dropdown(options=train_ds.fileNames, description='File:', layout={'width': 'initial'})
slider = widgets.IntSlider(min=0, max=getFileCount(train_ds.fileNames[0]), value=0, description='Slider:')

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        slider.max = getFileCount(change['new'])
        if slider.value > slider.max:
            slider.value = 0
        # print(change['new'], slider.value)
        updateFn(plotState, train_ds, hyperParameterDict, [change['new'], slider.value, None, None, None])

def on_change_slider(change):
    if change['type'] == 'change' and change['name'] == 'value':   
        # print(change['new'])
        updateFn(plotState, train_ds, hyperParameterDict, [dropdown.value, change['new'], None, None, None])

dropdown.observe(on_change)
slider.observe(on_change_slider)

display(dropdown)
display(slider)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 10
#       5 # datasetPath = 'datasets/SFBC_dataset_I/dataset'
#       6 # datasetPath = 'datasets/SFBC_dataset_II/dataset/train'
#       7 # datasetPath = 'datasets/SFBC_dataset_III/dataset/train'
#       8 datasetPath = '/home/yusuf/Physics_Emulators_using_Continuous_Convolutions/data/SFBC/SFBC_dataset_IV/dataset'
# ---> 10 train_ds = datasetLoader(processFolder(hyperParameterDict, datasetPath))
#      12 plotState = getPreparePlotFunction(train_ds.fileFormat)(train_ds, hyperParameterDict)
#      13 updateFn = getUpdatePlotFunction(train_ds.fileFormat)
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/dataloader.py:50, in processFolder(hyperParameterDict, folder)
#      48 for s in simulationFiles:
#      49     inFile = h5py.File(s, 'r')
# ---> 50     data.append(parseFile(inFile, hyperParameterDict))
#      51     inFile.close()
#      52 return data
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/datautils.py:318, in parseFile(inFile, hyperParameterDict)
#     314 skip *= frameDistance
#     315 limit = hyperParameterDict['dataLimit'] if 'dataLimit' in hyperParameterDict else 0
# --> 318 frames, samples = getSamples(inFile, frameSpacing = frameSpacing, frameDistance = frameDistance, maxRollout = maxRollout, skip = skip, limit = limit)
#     320 data= {'fileName': inFile.filename, 'frames': frames, 'samples': samples, 'frameDistance': frameDistance, 'frameSpacing': frameSpacing, 'maxRollout': maxRollout, 'skip': skip, 'limit': limit, 'isTemporalData': temporalData, 'style': getStyle(inFile)}
#     321 # print(data)
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/datautils.py:257, in getSamples(inFile, frameSpacing, frameDistance, maxRollout, skip, limit)
#     254 frames, samples = getFrames(inFile)
#     256 if maxRollout > 0 and not temporalData:
# --> 257     raise ValueError('Max rollout only supported for temporal data')
#     258 if frameCount < maxRollout:
#     259     raise ValueError('Max rollout larger than frame count')
#
# ValueError: Max rollout only supported for temporal data

# %%
len(train_ds.fileNames)
# Out:
# 64

# %%
from BasisConvolution.util.hyperparameters import parseHyperParameters, setSeeds, finalizeHyperParameters

# %%
# import warnings
# from datetime import datetime
# import torch
# import numpy as np
# import random

# %%
# datasetPath = '~/dev/SFBC/datasets/test_case_I'

# %%
# hyperParameterDict = parseHyperParameters("", None)
# hyperParameterDict['fluidFeatures'] = 'constant:1' if train_ds.fileFormat != 'testcase_IV' else 'attribute:a'
# hyperParameterDict['boundaryFeatures'] = 'constant:1'
# hyperParameterDict['groundTruth'] = 'compute[rho]:constant:1/constant:rho0'
# hyperParameterDict['frameDistance'] = 0
# hyperParameterDict['maxUnroll'] = 1
# hyperParameterDict['basisFunctions'] = 'ffourier_even'
# hyperParameterDict['device'] = 'cuda'
# hyperParameterDict['dtype'] = torch.float32

# train_ds = datasetLoader(processFolder(hyperParameterDict, datasetPath))

# finalizeHyperParameters(hyperParameterDict, train_ds)

# # print(hyperParameterDict['progressLabel'])

# %%
# hyperParameterDict['layers']

# %%
# fluidFeatureCount = hyperParameterDict['fluidFeatureCount']
# boundaryFeaturecount = hyperParameterDict['boundaryFeatureCount']
# layers = hyperParameterDict['layers']
# coordinateMapping = hyperParameterDict['coordinateMapping']
# windowFunction = getWindowFunction(hyperParameterDict['windowFunction'])

# rbfs = hyperParameterDict['rbfs']
# dims = hyperParameterDict['dims']

# cutlassBatchSize = hyperParameterDict['cutlassBatchSize']
# normalized = hyperParameterDict['normalized']
# outputBias = hyperParameterDict['outputBias']
# initializer = hyperParameterDict['initializer']
# optimizeWeights = hyperParameterDict['optimizeWeights']
# exponentialDecay = hyperParameterDict['exponentialDecay']
# inputEncoder = hyperParameterDict['inputEncoder'] if 'inputEncoder' in hyperParameterDict else None
# outputDecoder = hyperParameterDict['outputDecoder'] if 'outputDecoder' in hyperParameterDict else None
# edgeMLP = hyperParameterDict['edgeMLP'] if 'edgeMLP' in hyperParameterDict else None
# vertexMLP = hyperParameterDict['vertexMLP'] if 'vertexMLP' in hyperParameterDict else None


# print(f'fluidFeatureCount: {fluidFeatureCount}')
# print(f'boundaryFeaturecount: {boundaryFeaturecount}')
# print(f'layers: {layers}')
# print(f'coordinateMapping: {coordinateMapping}')
# print(f'windowFunction: {windowFunction}')

# print(f'rbfs: {rbfs}')
# print(f'dims: {dims}')

# print(f'cutlassBatchSize: {cutlassBatchSize}')
# print(f'normalized: {normalized}')
# print(f'outputBias: {outputBias}')
# print(f'initializer: {initializer}')
# print(f'optimizeWeights: {optimizeWeights}')
# print(f'exponentialDecay: {exponentialDecay}')
# print(f'inputEncoder: {inputEncoder}')
# print(f'outputDecoder: {outputDecoder}')
# print(f'edgeMLP: {edgeMLP}')
# print(f'vertexMLP: {vertexMLP}')

# %%
# def runInference(perennialState, config, model, batches = 1, verbose = False):
#     i, j = perennialState['fluid']['neighborhood']['indices']
#     distances = perennialState['fluid']['neighborhood']['distances'].view(-1,1) * perennialState['fluid']['neighborhood']['vectors']
#     return model(perennialState['fluid']['features'], i, j, distances, verbose = verbose)

# %%
from BasisConvolution.util.arguments import parser
import shlex
from torch.optim import Adam

# %%
# display(model)

# %%
# datasetPath = '~/dev/SFBC/datasets/test_case_II/train'

# args = parser.parse_args(shlex.split(f'--boundaryFeatures constant:1 --fluidFeatures constant:1 --groundTruth compute[rho]:constant:1/constant:rho0 --basisFunctions {basisFunction} --basisTerms {basisTerms} --windowFunction {windowFunction} --maxUnroll 0 --frameDistance 0 --epochs 1'))

# hyperParameterDict = parseHyperParameters(args, None)
# hyperParameterDict['device'] = 'cuda'
# hyperParameterDict['iterations'] = 2**10

# train_ds = datasetLoader(processFolder(hyperParameterDict, datasetPath))
# print(len(train_ds))
# train_loader = DataLoader(train_ds, shuffle=True, batch_size = hyperParameterDict['batchSize']).batch_sampler
# train_iter = iter(train_loader)

# finalizeHyperParameters(hyperParameterDict, train_ds)

# # print(hyperParameterDict['progressLabel'])

# model, optimizer, scheduler = buildModel(hyperParameterDict, verbose = True)

# model = model.train()

# losses = []
# psnrs = []
# bdatas = []
# # bdata = next(train_iter)
# for i in (t:=tqdm(range(hyperParameterDict['totalIterations']), leave = False)):
#     try:
#         bdata = next(train_iter)
#     except StopIteration:
#         train_iter = iter(train_loader)
#         bdata = next(train_iter)
#     bdatas.append(bdata)
#     config, attributes, currentState, priorState, trajectoryStates = loadAugmentedFrame(bdata[0], train_ds, hyperParameterDict)

#     optimizer.zero_grad()
#     prediction = runInference(currentState, config, model, verbose = True)

#     break

# %%
hyperParameterDict['device']
# Out:
# 'cpu'

# %%
# datasetPath = '~/dev/SFBC/datasets/test_case_II/train'
basisFunction = 'ffourier'
basisTerms = 4
windowFunction = 'None'

args = parser.parse_args(shlex.split(f'--fluidFeatures constant:1 --boundaryFeatures constant:1 --groundTruth compute[rho]:constant:1/constant:rho0 --basisFunctions {basisFunction} --basisTerms {basisTerms} --windowFunction {windowFunction} --maxUnroll 0 --frameDistance 0 --epochs 1'))

hyperParameterDict = parseHyperParameters(args, None)
hyperParameterDict['device'] = 'cuda'
hyperParameterDict['iterations'] = 2**10

train_ds = datasetLoader(processFolder(hyperParameterDict, datasetPath))
print(len(train_ds))
train_loader = DataLoader(train_ds, shuffle=True, batch_size = hyperParameterDict['batchSize']).batch_sampler
train_iter = iter(train_loader)

finalizeHyperParameters(hyperParameterDict, train_ds)

config, attributes, currentState, priorState, trajectoryStates = loadAugmentedFrame(123, train_ds, hyperParameterDict)
# Out:
# 2050
# Unroll length  1  exceeds maximum, limiting to 0
# loading frame 894281 using testcase IV
# /home/yusuf/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/hyperparameters.py:740: UserWarning: Boundary data requested but not available. Disabling boundary data.
#   warnings.warn('Boundary data requested but not available. Disabling boundary data.')
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 165361 using testcase IV

# %%
import pandas as pd
from BasisConvolution.util.hyperparameters import make_hash, toPandaDict
from BasisConvolution.util.network import buildModel, runInference
database = pd.DataFrame()

# %%
models = []

t = None
basisFunctions = ['ffourier', 'linear', 'ffourier_even', 'ffourier_odd', 'chebyshev']
for basisFunction in basisFunctions:
    # for basisTerms in [2,4,8]:
    for basisTerms in [4]:
        for windowFunction in ['None']:
            # print('Training for ', basisFunction, basisTerms, windowFunction)
            # args = parser.parse_args(shlex.split(f'--fluidFeatures attribute:a --groundTruth compute[rho]:constant:1/constant:rho0 --basisFunctions {basisFunction} --basisTerms {basisTerms} --windowFunction {windowFunction} --maxUnroll 0 --frameDistance 0 --epochs 1'))
            args = parser.parse_args(shlex.split(f'--fluidFeatures constant:1 --boundaryFeatures constant:1 --groundTruth compute[rho]:constant:1/constant:rho0 --basisFunctions {basisFunction} --basisTerms {basisTerms} --windowFunction {windowFunction} --maxUnroll 0 --frameDistance 0 --epochs 1'))

            hyperParameterDict = parseHyperParameters(args, None)
            hyperParameterDict['device'] = 'cuda'
            hyperParameterDict['iterations'] = 2**10
            # t.


            train_ds = datasetLoader(processFolder(hyperParameterDict, datasetPath))
            # print(len(train_ds))
            train_loader = DataLoader(train_ds, shuffle=True, batch_size = hyperParameterDict['batchSize']).batch_sampler
            train_iter = iter(train_loader)

            finalizeHyperParameters(hyperParameterDict, train_ds)

            if t is None:
                t = tqdm(range(hyperParameterDict['totalIterations']))
            t.reset( hyperParameterDict['totalIterations'])
            # t.n =
            t.set_description(f'{basisFunction} - {basisTerms} - {windowFunction}')

# print(hyperParameterDict['progressLabel'])

            model, optimizer, scheduler = buildModel(hyperParameterDict, verbose = False)

            model = model.train()

            losses = []
            psnrs = []
            bdatas = []
            # bdata = next(train_iter)
            for i in (range(hyperParameterDict['totalIterations'])):
                try:
                    bdata = next(train_iter)
                except StopIteration:
                    train_iter = iter(train_loader)
                    bdata = next(train_iter)
                bdatas.append(bdata)
                config, attributes, currentState, priorState, trajectoryStates = loadAugmentedFrame(bdata[0], train_ds, hyperParameterDict)

                optimizer.zero_grad()
                prediction = runInference(currentState, config, model, verbose = False)
                gt = trajectoryStates[0]['fluid']['target']

                loss = torch.nn.functional.mse_loss(prediction, gt)
                
                psnr = 20 * torch.log10(gt.abs().max()) - 10 * torch.log10(loss)

                loss.backward()
                losses.append(loss.item())
                psnrs.append(psnr.item())
                optimizer.step()
                t.set_description(f'{bdata} - {hyperParameterDict["progressLabel"]} - Loss: {loss.item():.4e}, PSNR: {psnr.item():.2f} [max: {gt.abs().max():.2g}]')
                t.update()
                t.refresh()
            dataFrame = pd.DataFrame([toPandaDict(hyperParameterDict)] * len(bdatas))

            dataFrame['batches'] = bdatas
            dataFrame['losses'] = losses
            dataFrame['psnrs'] = psnrs
            dataFrame['iteration'] = np.arange(len(bdatas))

            database = pd.concat([database, dataFrame], ignore_index = True)
            models.append(model)

            # break
        # break
    # break
# Out:
# Unroll length  1  exceeds maximum, limiting to 0
# loading frame 894281 using testcase IV
# /home/yusuf/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/hyperparameters.py:740: UserWarning: Boundary data requested but not available. Disabling boundary data.
#   warnings.warn('Boundary data requested but not available. Disabling boundary data.')
#   0%|          | 0/1024 [00:00<?, ?it/s]
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 971663 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 863338 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 489366 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 905556 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 918040 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 79970 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 780233 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 32439 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 712883 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 649032 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 868350 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 598765 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 136683 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 72009 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 151098 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 506281 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 316549 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 834226 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 718175 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 425030 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 61191 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 68525 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 302390 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 367670 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 294407 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 246777 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 900234 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 283099 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 527686 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 574979 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1010725 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 701932 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 176112 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 183893 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 659864 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 604079 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 488824 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 561412 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 625837 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 179265 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 921374 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 940974 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 993731 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 836531 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 526702 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 135741 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1013696 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 584001 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 289186 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 806596 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 304064 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 392433 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 752681 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 811506 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 866468 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 96243 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 5114 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 513956 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 541570 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 960372 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 507339 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 699341 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 974291 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 561135 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 311491 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 657823 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 733932 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 13384 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 220107 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1040308 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 742954 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 595635 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 869175 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 134623 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 589595 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 204993 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 504986 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 42609 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 555423 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 230464 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 182039 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 767748 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 534063 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 405992 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 352707 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 412947 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 4196 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 105910 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 992487 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 41860 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 831794 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 672860 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 39476 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 94589 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 896361 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 30109 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 576475 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 35358 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 710211 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 235274 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 367126 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 797969 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 346463 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 806446 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 348285 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 460566 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 229584 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 378048 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 68861 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 191766 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 26272 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 201677 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 894794 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 35313 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 547465 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 313780 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 231089 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 98877 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 788228 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 553671 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 873972 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 294412 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 735614 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 919426 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 566907 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 246452 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 331506 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 340179 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 184388 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 573082 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 169854 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 453472 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 991927 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 145952 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 669945 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 50930 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1044342 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 826197 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 347952 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 972571 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 952465 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 155682 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 8659 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 854696 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 902952 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 739329 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 967537 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1030347 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 461830 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1044646 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 440303 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 814142 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 343294 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1036375 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 846221 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 495369 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1008788 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 546251 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 966694 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 396583 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 705711 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 702355 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 945988 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 252941 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 79047 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 545782 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 327485 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 224189 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 127467 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 644444 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 457513 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 506835 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 636391 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 921280 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 640671 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 541834 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 104472 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 766408 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 621445 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 289030 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1006771 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1009580 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 981270 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 285454 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 855040 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 828968 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 900085 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 794618 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 285068 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 313018 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 944016 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 88166 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 756008 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 825609 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 517121 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 128562 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 725226 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 385762 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 721499 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 322848 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 722006 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 337707 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 600469 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 148113 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1000537 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 81811 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 67349 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 778523 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 522322 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1011855 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 305814 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 81127 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 297148 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 823424 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 63584 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 929175 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 278249 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 254505 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 224126 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 615834 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 895354 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 553365 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 420495 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 26485 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 373703 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 843512 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 923357 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 322391 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 165341 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 885630 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1005130 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 943508 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 449250 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1013372 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 698046 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 953315 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 796444 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 541866 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 213491 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 186812 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 708774 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1043578 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 58336 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 950725 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 635222 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 27238 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 391840 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 130923 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 134986 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 242051 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 318424 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 736467 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 460369 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 872448 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 881409 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 754430 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 806827 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 63125 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 776516 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 159332 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 892011 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 968277 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 366094 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 849260 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 288070 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 553600 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 950246 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 212425 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 930281 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 55704 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 706023 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 992631 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 507693 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 976922 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 838994 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 7133 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 161071 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 948746 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 736452 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1022609 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 887567 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 922455 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1005078 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 271932 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 664804 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 941036 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1027777 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 191049 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 47352 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 226155 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 166807 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 536164 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 529617 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 130550 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 184217 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 568831 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 790601 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 851617 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 164267 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 534769 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 45765 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 929972 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 334346 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 705364 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 866452 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 306687 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 552896 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 30819 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 258280 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 262139 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 146697 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 424747 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 722077 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 540711 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1032695 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 671592 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 24133 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 171760 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 169224 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 942491 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 307138 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 756074 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 230573 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 404480 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 999291 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 29063 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 444381 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 962457 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1041251 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 810806 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 633250 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 202747 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 724675 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 91129 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 29075 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 600932 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 188685 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 801417 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1021489 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 917913 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 25245 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 879745 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 742110 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 414212 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 381865 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 852556 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 188311 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1040204 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 864788 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 315132 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 71853 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 380380 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 451428 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 651559 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 516441 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 480204 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 233541 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 521062 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 429314 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 513800 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 825078 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 314504 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 425845 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 857259 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 225256 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 747656 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 414145 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 362698 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 929078 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 756316 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 941056 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 185777 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 168275 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 320716 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1032625 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 950253 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 139310 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 668725 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 192302 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 207652 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 219148 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 674005 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 443816 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 365383 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 330452 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 303918 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 258119 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 32082 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 730191 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 792144 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 247357 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 905762 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 811009 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 488844 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 775123 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 80076 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 682376 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 360928 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 273918 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 389633 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 40970 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 688869 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 787941 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 332035 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 220559 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 794359 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 634420 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 80009 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 536088 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 744272 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 820575 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 721678 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 990567 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 192203 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 278565 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 690370 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 748146 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 167628 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 708050 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 734539 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1011700 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 839989 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 731449 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 297232 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 898089 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 89052 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 703197 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 181350 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1042709 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 104384 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 831061 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 914665 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 653424 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 833829 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 172036 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 942024 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 328439 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 563973 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 632768 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 876107 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 563199 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 167574 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 665621 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 622967 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 140148 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 393573 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 460481 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 471682 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 618035 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 227883 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 230998 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 56373 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 551363 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 723961 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 328771 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 994813 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 195949 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 610408 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 267330 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 551435 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 843409 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 802415 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 253089 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 953570 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 271526 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 273298 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 26925 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 951467 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 551747 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 78812 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 324461 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 948506 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 361658 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 963365 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 383056 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1026914 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 981558 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 33860 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 53509 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 518721 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 633272 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 233980 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 183701 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 173722 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 808145 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 954501 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 63904 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 790812 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 474492 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 540823 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 86808 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 395499 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 798549 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 283040 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 678820 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 256346 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 653186 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 918048 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 268126 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 907330 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1018157 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 589243 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 653558 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 765485 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 840256 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 55159 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 134469 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 413889 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 232499 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 79835 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1005254 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 803449 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 486175 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 127991 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 60381 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 469684 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 183989 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 63504 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 411861 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 34348 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 909607 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 125985 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 281876 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 25891 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1026129 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 712233 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 231043 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 925314 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 975133 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 391414 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 450227 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 50417 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 599597 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 178666 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 43067 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 580213 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 995108 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 582110 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1037273 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 894627 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 262196 using testcase IV
# ...
# loading frame 333135 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 705420 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 431518 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 314017 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 171929 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 726492 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 621260 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 935283 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 146830 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 991999 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1013811 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 113755 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 557021 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 642626 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 258737 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 678300 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 199853 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 837079 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 923280 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1002563 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 432535 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 963392 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 330956 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 752057 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 361277 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 76249 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 29867 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1005479 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 232526 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 635236 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 317038 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 181981 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 98315 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 417339 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 694397 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 988633 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 769227 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 748928 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 482618 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 488966 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 973341 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 250691 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 664006 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 266006 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1016674 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 472157 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 610880 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 547675 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 871004 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 45948 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 497545 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 203000 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 938059 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 528567 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 12384 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 668455 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 904988 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 466985 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 721508 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 222075 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 712780 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 45841 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 930882 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 29464 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 520025 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 764642 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 868300 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 383350 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 137847 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 381353 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 882758 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 384410 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 460656 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 873548 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 598608 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 636746 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 111216 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 20031 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 332587 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1033047 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 192723 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 38441 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 75117 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 304088 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 125369 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 598959 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 228154 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 378930 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 461149 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 515072 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 399525 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 55526 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 36508 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 455834 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 271688 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 179345 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 365351 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 245352 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 196450 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 294905 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 348607 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 507444 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 72319 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 745338 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 814273 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 622090 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 934553 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 708369 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 555364 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 372190 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1009941 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 623782 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 978288 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 923304 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 208726 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 878496 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 694308 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 53305 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 430993 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 597392 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 591516 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 835936 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 266315 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 21854 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 653592 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 970452 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 981254 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 453370 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 306219 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 837014 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 228223 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 398009 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 725915 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 255559 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 574300 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 230664 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 64840 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 803036 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 93170 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 25343 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 834237 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 96920 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 44214 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 200177 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 525178 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1021174 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 49363 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 586103 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 586395 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 432751 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 828081 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 753052 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 862932 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 107896 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 750534 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 133743 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 793500 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 557768 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 644391 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 131533 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 167404 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 495419 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 236872 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 760899 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 593409 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 938556 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 896546 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1046937 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 694496 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 570255 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1029748 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 512692 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 727781 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 432606 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 907464 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 542662 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 992579 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 942982 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 481845 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 432174 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 783590 using testcase IV
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 3582 using testcase IV

# %%
import seaborn as sns
from scipy.ndimage.filters import gaussian_filter1d
# Out:
# /tmp/ipykernel_33065/3451570809.py:2: DeprecationWarning: Please import `gaussian_filter1d` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import gaussian_filter1d

# %%
basisTerms = database['basisTerms'].unique()
basisFunctions = database['basisFunctions'].unique()

print(basisTerms)
print(basisFunctions)

hues = sns.color_palette(n_colors = len(basisFunctions))
linestyles = ['--', '-', ':', '-.']
# Out:
# [4]
# ['ffourier' 'linear' 'ffourier_even' 'ffourier_odd' 'chebyshev']

# %%
fig, axis = plt.subplots(1,2, figsize = (10,4), sharey = False, squeeze= False)

for i, basisFunction in enumerate(basisFunctions):
    for j, basisTerm in enumerate(basisTerms):
        subDatabase = database[(database['basisFunctions'] == basisFunction) & (database['basisTerms'] == basisTerm)]
        # subDatabase = subDatabase[subDatabase['dimension'] == 3]

        iters = subDatabase['iteration']
        losses = subDatabase['losses']
        psnrs = subDatabase['psnrs']

        losses = gaussian_filter1d(losses, sigma = 5)
        psnrs = gaussian_filter1d(psnrs, sigma = 5)

        axis[0,0].plot(iters, losses, label = f'{basisFunction} - {basisTerm}', color = hues[i], ls = linestyles[j])
        axis[0,1].plot(iters, psnrs, label = f'{basisFunction} - {basisTerm}', color = hues[i], ls = linestyles[j])

axis[0,0].set_yscale('log')
axis[0,0].set_xlabel('Iteration')
axis[0,0].set_ylabel('Loss')
# axis[0,0].legend(ncol = 2)

axis[0,1].set_xlabel('Iteration')
axis[0,1].set_ylabel('PSNR')

handles, labels = axis[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol = 5,bbox_to_anchor=(0.5, 0.95))

fig.suptitle('Training process')
fig.subplots_adjust(top = 0.725)
# fig.bbox_inches = 'tight'

# fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s = 0.5
config, attributes, currentState, priorState, trajectoryStates = loadAugmentedFrame(1052, train_ds, hyperParameterDict)
# if currentState['fluid']['positions'].shape[1] == 2:
deAugmentedState = augmentState(copy.deepcopy(currentState), augRotation = currentState['augmentRotation'].T if 'augmentRotation' in currentState else None, augmentFeatures=False)
visualizationState = prepVisualizationState(deAugmentedState, config)


fig, axis = plt.subplots(2,3, figsize = (12,6), sharey = False, squeeze= False)

plotState = visualizeParticleQuantity(fig, axis[0,0], config, visualizationState, quantity = trajectoryStates[0]['fluid']['target'], mapping = '.x', s = s*4, 
                            scaling = 'lin', gridVisualization=False, cmap = 'twilight', title = 'Ground Truth', plotBoth=True, which = 'fluid')

for ax, model, basis in zip(axis.flatten()[1:], models, basisFunctions):

    prediction = runInference(currentState, config, model, verbose = False)
    loss = (prediction - trajectoryStates[0]['fluid']['target'])**2
    plotState = visualizeParticleQuantity(fig, ax, config, visualizationState, quantity = loss, mapping = '.x', s = s*4, 
                            scaling = 'lin', gridVisualization=False, cmap = 'viridis', title = f'{basis} - Prediction', plotBoth=True, which = 'fluid')


for ax in axis.flatten():
    ax.set_xlim(-1.1,1.1)
    ax.set_ylim(-1.1,1.1)


fig.tight_layout()
# Out:
# Unroll length  8  exceeds maximum, limiting to 0
# loading frame 1030810 using testcase IV
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[25], line 5
#       3 # if currentState['fluid']['positions'].shape[1] == 2:
#       4 deAugmentedState = augmentState(copy.deepcopy(currentState), augRotation = currentState['augmentRotation'].T if 'augmentRotation' in currentState else None, augmentFeatures=False)
# ----> 5 visualizationState = prepVisualizationState(deAugmentedState, config)
#       8 fig, axis = plt.subplots(2,3, figsize = (12,6), sharey = False, squeeze= False)
#      10 plotState = visualizeParticleQuantity(fig, axis[0,0], config, visualizationState, quantity = trajectoryStates[0]['fluid']['target'], mapping = '.x', s = s*4,
#      11                             scaling = 'lin', gridVisualization=False, cmap = 'twilight', title = 'Ground Truth', plotBoth=True, which = 'fluid')
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/plotting.py:84, in prepVisualizationState(perennialState, config, nGrid, fluidNeighborhood, grid)
#      82     gridConfig['simulation']['supportScheme'] = 'scatter'
#      83     # printState(gridState)
# ---> 84     _, visualizationState['gridNeighborhood'] = neighborSearch(gridState, visualizationState['fluid'], gridConfig) #0, perennialState['fluid']['supports'], getKernel('Wendland2'), config['domain']['dim'], config['domain']['periodicity'], config['domain']['minExtent'], config['domain']['maxExtent'], mode = 'scatter', algorithm ='compact')
#      85     # visualizationState['gridNeighborhood'] = {}
#      86     # visualizationState['gridNeighborhood']['indices'] = (i, j)
#      87     # visualizationState['gridNeighborhood']['distances'] = rij
#    (...)     90     # visualizationState['gridNeighborhood']['gradients'] = gradWij
#      91     # visualizationState['gridNeighborhood']['supports'] = hij
#      93 return visualizationState
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/sph/neighborhood.py:155, in neighborSearch(queryState, referenceState, config, computeKernels, priorState, neighborDatastructure, verbose)
#     153     neighborhood = neighborSearchExisting(queryState['positions'], queryState['supports'], neighborDatastructure, 'scatter', 1, 'cpp')
#     154 else:
# --> 155     neighborhood = radiusSearch(queryState['positions'], referenceState['positions'], support = queryState['supports'] * config['neighborhood']['verletScale'], mode = 'gather', domainMin = config['domain']['minExtent'], domainMax = config['domain']['maxExtent'], periodicity = config['domain']['periodicity'], algorithm = 'naive')
#     156 numNeighbors_full = countUniqueEntries(neighborhood[0], queryState['positions'])[1].to(torch.int32)
#     157 neighborOffsets_full = torch.hstack((torch.tensor([0], dtype = torch.int32, device = numNeighbors_full.device), torch.cumsum(numNeighbors_full, dim = 0).to(torch.int32)))[:-1]\
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/neighborhoodFallback/neighborhood.py:27, in radiusSearch(queryPositions, referencePositions, support, fixedSupport, mode, domainMin, domainMax, periodicity, hashMapLength, algorithm, verbose, returnStructure)
#      25 assert algorithm in ['naive'], f'algorithm = {algorithm} not supported'
#      26 assert mode in ['symmetric', 'scatter', 'gather'], f'mode = {mode} not supported'
# ---> 27 assert queryPositions.shape[1] == referencePositions.shape[1] if referencePositions is not None else True, f'queryPositions.shape[1] = {queryPositions.shape[1]} != referencePositions.shape[1] = {referencePositions.shape[1]}'
#      28 assert hashMapLength > 0, f'hashMapLength = {hashMapLength} <= 0'
#      29 assert periodicity.shape[0] == queryPositions.shape[1] if isinstance(periodicity, torch.Tensor) else True, f'len(periodicity) = {len(periodicity)} != queryPositions.shape[1] = {queryPositions.shape[1]}'
#
# AssertionError: queryPositions.shape[1] = 2 != referencePositions.shape[1] = 3

# %%
from diffSPH.v2.plotting import prepVisualizationState, visualizeParticleQuantity, updatePlot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from diffSPH.v2.plotting import prepVisualizationState, visualizeParticleQuantity, updatePlot
#
# ModuleNotFoundError: No module named 'diffSPH'

# %%
deAugmentedState = augmentState(copy.deepcopy(currentState), augRotation = currentState['augmentRotation'].T if 'augmentRotation' in currentState else None)
visualizationState = prepVisualizationState(currentState, config)

s = 0.5
fig, axis = plt.subplot_mosaic('''AABC
                               AADE''', figsize=(10,6), sharex = False, sharey = False)

featurePlot = visualizeParticleQuantity(fig, axis['B'], config, visualizationState, quantity = 'features', mapping = '.x', s = s, 
                          scaling = 'lin', gridVisualization=True, cmap = 'magma', title = 'Features')

predictionPlot = visualizeParticleQuantity(fig, axis['C'], config, visualizationState, quantity = prediction[:,0], mapping = '.x', s = s, 
                          scaling = 'lin', gridVisualization=True, cmap = 'viridis', title = 'Prediction')
groundTruthPlot = visualizeParticleQuantity(fig, axis['D'], config, visualizationState, quantity = gt, mapping = '.x', s = s, 
                          scaling = 'lin', gridVisualization=True, cmap = 'viridis', title = 'GT')

lossPlot = visualizeParticleQuantity(fig, axis['E'], config, visualizationState, quantity = prediction - gt, mapping = '.x', s = s, 
                          scaling = 'sym', gridVisualization=True, cmap = 'icefire', title = 'diff', midPoint=0.0)

nx = 128
xx = np.linspace(-1, 1, nx)
yy = np.linspace(-1, 1, nx)
X, Y = np.meshgrid(xx, yy)
positions = torch.tensor(np.stack([X.flatten(), Y.flatten()]).T, device = currentState['fluid']['positions'].device, dtype = currentState['fluid']['positions'].dtype)

centralPosition = torch.tensor([[0.0, 0.0]], device = currentState['fluid']['positions'].device, dtype = currentState['fluid']['positions'].dtype)

distances = (positions - centralPosition).norm(dim = 1).view(-1,1) * (positions - centralPosition)

synthetic_i = torch.arange(0, positions.shape[0], device = currentState['fluid']['positions'].device, dtype = torch.long).flatten()
synthetic_j = torch.zeros_like(synthetic_i)

synthetic_features = torch.ones(positions.shape[0], device = currentState['fluid']['positions'].device, dtype = currentState['fluid']['positions'].dtype).view(-1,1)

synthetic = model(synthetic_features, synthetic_i, synthetic_j, distances, verbose = False)

sc = axis['A'].pcolormesh(X, Y, synthetic[:,0].detach().cpu().numpy().reshape(nx, nx), cmap = 'viridis')
circle = plt.Circle((0, 0), 1, color='r', fill=False)
axis['A'].add_artist(circle)
axis['A'].set_aspect('equal')
axis['A'].set_title('Kernel')

for ax in axis.values():
    ax.set_xlabel(None)
    ax.set_ylabel(None)
    ax.set_xticklabels([])
    ax.set_yticklabels([])

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 deAugmentedState = augmentState(copy.deepcopy(currentState), augRotation = currentState['augmentRotation'].T if 'augmentRotation' in currentState else None)
# ----> 2 visualizationState = prepVisualizationState(currentState, config)
#       4 s = 0.5
#       5 fig, axis = plt.subplot_mosaic('''AABC
#       6                                AADE''', figsize=(10,6), sharex = False, sharey = False)
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/util/plotting.py:84, in prepVisualizationState(perennialState, config, nGrid, fluidNeighborhood, grid)
#      82     gridConfig['simulation']['supportScheme'] = 'scatter'
#      83     # printState(gridState)
# ---> 84     _, visualizationState['gridNeighborhood'] = neighborSearch(gridState, visualizationState['fluid'], gridConfig) #0, perennialState['fluid']['supports'], getKernel('Wendland2'), config['domain']['dim'], config['domain']['periodicity'], config['domain']['minExtent'], config['domain']['maxExtent'], mode = 'scatter', algorithm ='compact')
#      85     # visualizationState['gridNeighborhood'] = {}
#      86     # visualizationState['gridNeighborhood']['indices'] = (i, j)
#      87     # visualizationState['gridNeighborhood']['distances'] = rij
#    (...)     90     # visualizationState['gridNeighborhood']['gradients'] = gradWij
#      91     # visualizationState['gridNeighborhood']['supports'] = hij
#      93 return visualizationState
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/sph/neighborhood.py:155, in neighborSearch(queryState, referenceState, config, computeKernels, priorState, neighborDatastructure, verbose)
#     153     neighborhood = neighborSearchExisting(queryState['positions'], queryState['supports'], neighborDatastructure, 'scatter', 1, 'cpp')
#     154 else:
# --> 155     neighborhood = radiusSearch(queryState['positions'], referenceState['positions'], support = queryState['supports'] * config['neighborhood']['verletScale'], mode = 'gather', domainMin = config['domain']['minExtent'], domainMax = config['domain']['maxExtent'], periodicity = config['domain']['periodicity'], algorithm = 'naive')
#     156 numNeighbors_full = countUniqueEntries(neighborhood[0], queryState['positions'])[1].to(torch.int32)
#     157 neighborOffsets_full = torch.hstack((torch.tensor([0], dtype = torch.int32, device = numNeighbors_full.device), torch.cumsum(numNeighbors_full, dim = 0).to(torch.int32)))[:-1]\
#
# File ~/Physics_Emulators_using_Continuous_Convolutions/SFBC/src/BasisConvolution/neighborhoodFallback/neighborhood.py:27, in radiusSearch(queryPositions, referencePositions, support, fixedSupport, mode, domainMin, domainMax, periodicity, hashMapLength, algorithm, verbose, returnStructure)
#      25 assert algorithm in ['naive'], f'algorithm = {algorithm} not supported'
#      26 assert mode in ['symmetric', 'scatter', 'gather'], f'mode = {mode} not supported'
# ---> 27 assert queryPositions.shape[1] == referencePositions.shape[1] if referencePositions is not None else True, f'queryPositions.shape[1] = {queryPositions.shape[1]} != referencePositions.shape[1] = {referencePositions.shape[1]}'
#      28 assert hashMapLength > 0, f'hashMapLength = {hashMapLength} <= 0'
#      29 assert periodicity.shape[0] == queryPositions.shape[1] if isinstance(periodicity, torch.Tensor) else True, f'len(periodicity) = {len(periodicity)} != queryPositions.shape[1] = {queryPositions.shape[1]}'
#
# AssertionError: queryPositions.shape[1] = 2 != referencePositions.shape[1] = 3

# %%
visualizationState = prepVisualizationState(currentState, config)

for i in (t:=tqdm(range(1024))):
    optimizer.zero_grad()
    prediction = runInference(currentState, config, model, verbose = False)
    gt = trajectoryStates[0]['fluid']['target']

    loss = torch.nn.functional.mse_loss(prediction, gt)
    loss.backward()
    optimizer.step()
    t.set_description(f'Loss: {loss.item():.4e}')
    if i % 32 == 0:
        updatePlot(featurePlot, visualizationState, 'features')
        updatePlot(predictionPlot, visualizationState, prediction[:,0])
        updatePlot(groundTruthPlot, visualizationState, gt)
        updatePlot(lossPlot, visualizationState, prediction - gt)

        synthetic = model(synthetic_features, synthetic_i, synthetic_j, distances, verbose = False)
        sc.set_array(synthetic[:,0].detach().cpu().numpy().reshape(nx, nx).flatten())

        fig.canvas.draw()
        fig.canvas.flush_events()
    t.set_description(f'Loss: {loss.item():.4e}')
# Out:
#   0%|          | 0/1024 [00:00<?, ?it/s]

# %%
# train_ds = datasetLoader(processFolder(hyperParameterDict, '~/dev/diffSPH/generative/dataset_dfsph/export'))
config, attributes, currentState, priorState, trajectoryStates = loadAugmentedFrame(1024, train_ds, hyperParameterDict)

optimizer.zero_grad()
prediction = runInference(currentState, config, model, verbose = False)
gt = trajectoryStates[0]['fluid']['target']

loss = torch.nn.functional.mse_loss(prediction, gt)
# loss.backward()
# optimizer.step()
# Out:
# tensor(0.4854, grad_fn=<MseLossBackward0>)

# %%
# print(synthetic)

# %%
print(synthetic_i)
print(synthetic_j)
print(synthetic)
# Out:
# tensor([   0,    1,    2,  ..., 1021, 1022, 1023])
# tensor([0, 0, 0,  ..., 0, 0, 0])
# tensor([[ 0.0382],
#         [ 0.0382],
#         [ 0.0382],
#         ...,
#         [-0.0071],
#         [-0.0071],
#         [-0.0071]], grad_fn=<cutlassBackward>)

# %%
fig, axis = plt.subplot_mosaic('''AABC
                               AADE''', figsize=(10,5), sharex = False, sharey = False)

# sc = axis['B'].imshow(distances[:,0].detach().cpu().numpy().reshape(16,16), cmap = 'viridis')
sc = axis['B'].scatter(positions[:,0].detach().cpu().numpy(), positions[:,1].detach().cpu().numpy(), c = distances[:,0].detach().cpu().numpy(), cmap = 'viridis')
fig.colorbar(sc, ax = axis['B'])
# sc = axis['C'].imshow(distances[:,1].detach().cpu().numpy().reshape(16,16), cmap = 'viridis')
sc = axis['C'].scatter(positions[:,0].detach().cpu().numpy(), positions[:,1].detach().cpu().numpy(), c = distances[:,1].detach().cpu().numpy(), cmap = 'viridis')
fig.colorbar(sc, ax = axis['C'])

sc = axis['A'].scatter(positions[:,0].detach().cpu().numpy(), positions[:,1].detach().cpu().numpy(), c = synthetic[:,0].detach().cpu().numpy(), cmap = 'viridis')

sc = axis['A'].pcolormesh(X, Y, synthetic[:,0].detach().cpu().numpy().reshape(nx, nx), cmap = 'viridis')

fig.tight_layout()

# %%
    i, j = perennialState['fluid']['neighborhood']['indices']
    distances = perennialState['fluid']['neighborhood']['distances'].view(-1,1) * perennialState['fluid']['neighborhood']['vectors']
    return model(perennialState['fluid']['features'], i, j, distances, verbose = verbose)

# %%
config['particle']['support']
# Out:
# 0.059292720702474794

# %%
currentState['fluid']['supports']
# Out:
# tensor([0.0593, 0.0593, 0.0593,  ..., 0.0593, 0.0593, 0.0593])

# %%
# visualizationState

# %%
config['kernel']
# Out:
# {'kernelScale': tensor(1.8974),
#  'name': 'Wendland2',
#  'targetNeighbors': 45.238956,
#  'function': <diffSPH.kernels.KernelWrapper at 0x7e525f037c50>}

# %%
from features import getFeatures

# %%
searchNeighbors(priorState, config, True)

# %%
import copy
from augment import augmentState
from diffSPH.v2.plotting import prepVisualizationState, visualizeParticleQuantity

# currentState['fluid']['features'] = getFeaturev2('attribute@rho / attribute@rho', currentState['fluid'], priorState['fluid'], config)
# currentState['fluid']['features'] = getFeatures(['attribute@u.x', 'attribute@u.y'], currentState['fluid'], priorState['fluid'], config)
# currentState['fluid']['features'] = getFeatures(['attribute:x*constant:-1'], currentState['fluid'], priorState['fluid'], config)

currentState['fluid']['features'] = getFeatures(['diff:compute[gradSym]:constant=1*attribute:rho'], currentState['fluid'], priorState['fluid'], config, currentState['time'] - priorState['time'])


deAugmentedState = augmentState(copy.deepcopy(currentState), augRotation = currentState['augmentRotation'].T if 'augmentRotation' in currentState else None)
visualizationState = prepVisualizationState(deAugmentedState, config)

s = 0.5
fig, axis = plt.subplot_mosaic('''ABC''', figsize=(13.5,5), sharex = False, sharey = False)

visualizeParticleQuantity(fig, axis['A'], config, visualizationState, quantity = 'indices', mapping = '.x', s = s, 
                          scaling = 'lin', gridVisualization=False, cmap = 'twilight', title = 'Particle Index')

visualizeParticleQuantity(fig, axis['B'], config, visualizationState, quantity = 'features', mapping = '.x', s = s, 
                          scaling = 'lin', gridVisualization=False, cmap = 'twilight', title = 'Particle Index')
visualizeParticleQuantity(fig, axis['C'], config, visualizationState, quantity = 'features', mapping = '.y', s = s, 
                          scaling = 'lin', gridVisualization=False, cmap = 'twilight', title = 'Particle Index')

fig.tight_layout()

# %%
config['fluid']
# Out:
# {'cs': 20, 'mu': 0.1, 'rho0': 1000}
